# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train = np.load('FireEvac_train_set.npy')
test = np.load('FireEvac_test_set.npy')

# %%
print(train.shape)
# Out:
# (3000, 2)

# %%
print(train)
# Out:
# [[ 86.6926273   62.44229187]
#  [ 75.54568175  78.16017028]
#  [123.44951903  85.43761181]
#  ...
#  [ 52.83179754  47.58244578]
#  [  6.72376937  49.55944998]
#  [ 34.11260284  43.68753151]]

# %%
fig = plt.figure()
plt.scatter(train[:,0], train[:,1])
plt.title('FireEvac_train_set')

plt.savefig('FireEvac_train_set.png')
plt.show()

# %%
fig = plt.figure()
plt.scatter(test[:,0], test[:,1])
plt.title('FireEvac_test_set')

plt.savefig('FireEvac_test_set.png')
plt.show()
