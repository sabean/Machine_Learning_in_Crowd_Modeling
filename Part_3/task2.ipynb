# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D

# %%
w = 1
Y, X = np.mgrid[-w:w:20j, -w:w:20j]
alpha = 0
x_0 = np.sqrt(alpha)
start = [[2,0]]
last = 100
iterations = 1000
X = np.linspace(0,1,100)
alpha = np.linspace(0,1,100)
alpha1 = np.linspace(0,1,100)
fig, ax1 = plt.subplots()
x_dot = alpha - X*X

x = np.sqrt((alpha))
x_1 = -np.sqrt((alpha))
x_2 = 0
alph0 = 0
#x_2 = np.linspace(0,0,100)
#x_3 = np.linspace(0,0,100)
ax1.plot(alpha, x,color='b')
ax1.plot(alpha,x_1,'--',color='b')
#ax1.plot(alpha1,x_2,color='b')
#ax1.plot(alpha,x_3,'--',color='b')
#x1.plot(alph0,x_2,color='b')
        
ax1.set_title("Bifurcation diagram")
plt.xlim(-1,1)
plt.xlabel('alpha')
plt.ylabel('x_0(alpha)')
plt.tight_layout()

# %%
w = 4
Y, X = np.mgrid[-w:w:20j, -w:w:20j]
alpha = 0
x_0 = np.sqrt(alpha)
start = [[2,0]]
last = 100
iterations = 1000
#X = np.linspace(-1,1,100)
alpha = np.linspace(2,4,100)
alpha1 = np.linspace(2,4,100)
#y =[]
fig, ax1 = plt.subplots()
#x_dot = alpha - X*X

x = np.sqrt((alpha/2) - 1)
x_1 = -np.sqrt((alpha/2) - 1)
#x_2 = np.linspace(0,0,100)
#x_3 = np.linspace(0,0,100)
#ax1.plot(alpha, x,color='b')
ax1.plot(alpha,x_1,'--',color='b')
ax1.plot(alpha1,x,color='b')
#ax1.plot(alpha,x_3,'--',color='b')
        
ax1.set_title("Bifurcation diagram")
plt.xlim(-1,4)
plt.xlabel('alpha')
plt.ylabel('x_0(alpha)')
plt.tight_layout()
